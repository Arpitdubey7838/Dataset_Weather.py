# %%
import pandas as pd

# %%
data = pd.read_csv(r"E:\weatherHistory.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.tail(2)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
data.shape
# Out:
# (96453, 12)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
data['Humidity'].unique()
# Out:
# array([0.89, 0.86, 0.83, 0.85, 0.95, 0.82, 0.72, 0.67, 0.54, 0.55, 0.51,
#        0.47, 0.46, 0.6 , 0.63, 0.69, 0.7 , 0.77, 0.76, 0.79, 0.62, 0.66,
#        0.8 , 0.78, 0.61, 0.52, 0.4 , 0.37, 0.36, 0.43, 0.5 , 0.53, 0.58,
#        0.59, 0.87, 0.93, 0.84, 0.73, 0.71, 0.74, 0.81, 0.9 , 0.99, 0.96,
#        0.75, 0.88, 0.65, 0.91, 0.94, 0.92, 0.44, 0.56, 0.68, 0.64, 0.48,
#        0.57, 0.98, 1.  , 0.38, 0.41, 0.45, 0.49, 0.32, 0.42, 0.35, 0.39,
#        0.97, 0.34, 0.33, 0.31, 0.3 , 0.29, 0.27, 0.28, 0.26, 0.24, 0.25,
#        0.23, 0.19, 0.17, 0.2 , 0.15, 0.18, 0.22, 0.14, 0.21, 0.16, 0.13,
#        0.  , 0.12])

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
data['Humidity'].value_counts()
# Out:
# Humidity
# 0.93    5708
# 0.92    3888
# 0.96    3843
# 1.00    2890
# 0.89    2837
#         ...
# 0.15      10
# 0.16       8
# 0.14       4
# 0.13       1
# 0.12       1
# Name: count, Length: 90, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ### Q1. find all the unique "wind speed" valaues in the data.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# ### Q2. find the number of times when the "Weather is exactly clear".

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
# value_counts()
data.Summary.value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
# filtering 
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.Summary == 'Clear'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 96448    False
# 96449    False
# 96450    False
# 96451    False
# 96452    False
# Name: Summary, Length: 96453, dtype: bool

# %%
data[data.Summary == 'Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
# groupby()
data.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# ### Q3. find the number of times when the 'wind speed was exactly 14 km/h".

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data['Wind Speed (km/h)'] == 14]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %% [markdown]
# ### Q4. find the null values in data.

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [markdown]
# ### Q5. rename the column name "summary of the dataframe to "weather codition'.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.rename(columns = {'Summary':'weather_condition'},inplace = True)
data.rename(columns = { 'Temperature (C)':'Temp'},inplace = True)

# %%
data.head(2)
# Out:
#                   Formatted Date weather_condition Precip Type      Temp  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain  9.472222
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain  9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %% [markdown]
# ### Q6. what is the mean 'Visibility'?

# %%
data.head(2)
# Out:
#                   Formatted Date weather_condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.columns = data.columns.str.strip()
data["Humidity"].mean()
# Out:
# np.float64(0.7348989663359355)

# %% [markdown]
# ### Q7.what is the standard deviation of 'pressure' in the data?

# %%
data.Humidity.std()
# Out:
# np.float64(0.1954727390672154)

# %% [markdown]
# ### q8.what is the variance of humidity in this data ?

# %%
data['Pressure (millibars)'].var()  # use when gap in the column name
# Out:
# np.float64(13681.9588353917)

# %% [markdown]
# ### Q9.find all inatance when 'snow' was recorded.

# %%
data.head(2)
# Out:
#                   Formatted Date weather_condition Precip Type      Temp  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain  9.472222
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain  9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data['weather_condition'].value_counts()
# Out:
# weather_condition
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# ...

# %%
#filtering 
data[data['weather_condition'] =='Partly Cloudy'].head(5)
# Out:
#                   Formatted Date weather_condition Precip Type      Temp  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain  9.472222
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain  9.355556
# 3  2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain  8.288889
# 5  2006-04-01 05:00:00.000 +0200     Partly Cloudy        rain  9.222222
# 6  2006-04-01 06:00:00.000 +0200     Partly Cloudy        rain  7.733333
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 3                  5.944444      0.83            14.1036
# 5                  7.111111      0.85            13.9587
# 6                  5.522222      0.95            12.3648
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
# str constrains
data[data['weather_condition'].str.contains('Foggy')].head(2)
# Out:
#                    Formatted Date weather_condition Precip Type       Temp  \
# 66  2006-04-11 18:00:00.000 +0200             Foggy        rain  10.911111
# 67  2006-04-11 19:00:00.000 +0200             Foggy        rain   8.800000
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 66                 10.911111      0.86            22.3951
# 67                  5.294444      0.99            26.5006
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 66                   311.0           2.6565         0.0               1004.61
# 67                   339.0           2.6565         0.0               1004.99
#
#             Daily Summary
# 66  Foggy in the evening.
# 67  Foggy in the evening.

# %% [markdown]
# ### Q10.Find all the instance when 'wind speed' is above 24 and visibility is 25

# %%
data[(data['Wind Speed (km/h)'] >24) & (data['Visibility (km)'] >16)]
# Out:
#                       Formatted Date weather_condition Precip Type       Temp  \
# 16042  2007-11-08 11:00:00.000 +0100     Partly Cloudy        rain  10.238889
# 23583  2008-05-16 16:00:00.000 +0200     Mostly Cloudy        rain  24.488889
# 26400  2009-04-12 00:00:00.000 +0200             Clear        rain  14.444444
# 26778  2009-04-26 18:00:00.000 +0200     Partly Cloudy        rain  16.666667
# 26782  2009-04-26 22:00:00.000 +0200     Partly Cloudy        rain  11.666667
# ...                              ...               ...         ...        ...
# 93179  2016-03-24 14:00:00.000 +0100     Partly Cloudy        rain  10.000000
# 93186  2016-03-24 21:00:00.000 +0100     Partly Cloudy        rain   4.433333
# 93372  2016-03-31 16:00:00.000 +0200     Partly Cloudy        rain  22.777778
# 95613  2016-10-05 00:00:00.000 +0200          Overcast        rain   9.972222
# 96030  2016-09-20 09:00:00.000 +0200     Mostly Cloudy        rain  16.044444
#
# ...

# %% [markdown]
# ### Q11 . what is the mean value of each column against each 'Weather condition' ?

# %%
data.groupby('weather_condition').mean(numeric_only=True)
# Out:
#                                           Temp  Apparent Temperature (C)  \
# weather_condition
# Breezy                                7.922016                  3.387654
# Breezy and Dry                       21.111111                 21.111111
# Breezy and Foggy                     -0.510317                 -7.403492
# Breezy and Mostly Cloudy             11.093411                  8.680588
# Breezy and Overcast                   7.241614                  3.492235
# Breezy and Partly Cloudy             12.492761                  9.989349
# Clear                                11.925109                 11.040338
# Dangerously Windy and Partly Cloudy   8.944444                  3.483333
# Drizzle                              10.847578                 10.011681
# Dry                                  29.083660                 28.273529
# Dry and Mostly Cloudy                26.838492                 25.929365
# Dry and Partly Cloudy                26.605749                 25.982235
# ...

# %% [markdown]
# ### Q12. what is the minimum and maximum value of each column against each 'Weather codition'?

# %%
data.groupby('weather_condition').min(numeric_only=True)
# Out:
#                                           Temp  Apparent Temperature (C)  \
# weather_condition
# Breezy                               -2.777778                -10.411111
# Breezy and Dry                       21.111111                 21.111111
# Breezy and Foggy                     -3.827778                -11.905556
# Breezy and Mostly Cloudy             -6.966667                -15.972222
# Breezy and Overcast                 -11.533333                -21.716667
# Breezy and Partly Cloudy             -5.050000                -13.416667
# Clear                               -20.000000                -27.716667
# Dangerously Windy and Partly Cloudy   8.944444                  3.483333
# Drizzle                               7.805556                  4.938889
# Dry                                  20.000000                 20.000000
# Dry and Mostly Cloudy                20.072222                 20.072222
# Dry and Partly Cloudy                20.000000                 20.000000
# ...

# %%
data.groupby('weather_condition').max(numeric_only =True)
# Out:
#                                           Temp  Apparent Temperature (C)  \
# weather_condition
# Breezy                               37.588889                 35.700000
# Breezy and Dry                       21.111111                 21.111111
# Breezy and Foggy                     17.616667                 17.616667
# Breezy and Mostly Cloudy             27.522222                 27.766667
# Breezy and Overcast                  22.433333                 22.433333
# Breezy and Partly Cloudy             38.438889                 36.922222
# Clear                                39.905556                 38.661111
# Dangerously Windy and Partly Cloudy   8.944444                  3.483333
# Drizzle                              17.844444                 17.844444
# Dry                                  38.750000                 36.622222
# Dry and Mostly Cloudy                33.905556                 31.611111
# Dry and Partly Cloudy                37.800000                 35.672222
# ...

# %% [markdown]
# ### Q13. show all the records were weather codition is fog.

# %%
data[data['weather_condition']=='Foggy']
# Out:
#                       Formatted Date weather_condition Precip Type       Temp  \
# 66     2006-04-11 18:00:00.000 +0200             Foggy        rain  10.911111
# 67     2006-04-11 19:00:00.000 +0200             Foggy        rain   8.800000
# 72     2006-04-12 00:00:00.000 +0200             Foggy        rain   8.200000
# 73     2006-04-12 01:00:00.000 +0200             Foggy        rain   8.177778
# 126    2006-04-14 06:00:00.000 +0200             Foggy        rain   5.211111
# ...                              ...               ...         ...        ...
# 95858  2016-09-14 05:00:00.000 +0200             Foggy        rain  13.144444
# 95859  2016-09-14 06:00:00.000 +0200             Foggy        rain  13.822222
# 95860  2016-09-14 07:00:00.000 +0200             Foggy        rain  13.872222
# 95907  2016-09-16 06:00:00.000 +0200             Foggy        rain  14.905556
# 96228  2016-09-28 15:00:00.000 +0200             Foggy        rain  22.800000
#
# ...
